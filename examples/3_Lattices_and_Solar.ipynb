# %% [markdown]
# <heading style="color: black; font-size: 29px; line-height: 1.4; font-family: 'Times New Roman', Times, serif;">
# Example 3: Lattices and Solar<br>
# </heading>
# <div style="color: black; font-size: 18px; line-height: 1.4; font-family: 'Times New Roman', Times, serif;">
# This notebook shows how to calculate reflectance of a fibre in a lattice, and to compare that reflectance with the strength of solar radiation.
# </div>
